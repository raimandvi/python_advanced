# %% [markdown]
# <a href="https://colab.research.google.com/github/raimandvi/python_advanced/blob/main/decorators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Decorators in python
#
# Decorators are used to modify or extend the behaviour of a function without changing its original code.

# %% [markdown]
# **1. Simple Decorator**

# %%
def my_decorator(func):
    def wrapper():
        print("Before function execution")
        func()
        print("After function execution")
    return wrapper

def say_hello():
    print("Hello")

decorated_function = my_decorator(say_hello)
decorated_function()
# Out:
# Before function execution
# Hello
# After function execution

# %% [markdown]
# **2. Using @ Syntax**
#
# Cleaner Syntax
# Industry standard

# %%
def my_decorator(func):
    def wrapper():
        print("Before function")
        func()
        print("After function")
    return wrapper

@my_decorator
def welcome():
    print("Welcome to Python")

welcome()
# Out:
# Before function
# Welcome to Python
# After function

# %% [markdown]
# **3. Decorator with Arguments**

# %%
def my_decorator(func):
    def wrapper(*args, **kwargs):
        print("Function is running")
        return func(*args, **kwargs)
    return wrapper

@my_decorator
def add(a, b):
    return a + b

print(add(3, 4))
# Out:
# Function is running
# 7

# %% [markdown]
# **4. Multiple Decorators**

# %%
def decorator_one(func):
    def wrapper():
        print("Decorator One")
        func()
    return wrapper

def decorator_two(func):
    def wrapper():
        print("Decorator Two")
        func()
    return wrapper

@decorator_one
@decorator_two
def show():
    print("Hello")

show()
# Out:
# Decorator One
# Decorator Two
# Hello
