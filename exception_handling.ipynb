# %% [markdown]
# <a href="https://colab.research.google.com/github/raimandvi/python_advanced/blob/main/exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exception Handling in Python
#
# Exception handling is used to handle runtime errors so that the normal flow of the program is not interrupted.

# %% [markdown]
# **1. Simple try - except**
#
# concept: . Hnaldes runtime errors.
#          . Prevents program crash

# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))
    print("Result:", a / b)
except:
    print("Error occurred")
# Out:
# Enter a number: 5
# Enter another number: 0
# Error occurred

# %% [markdown]
# **2. Handling Specific Exceptions**

# %%
try:
  num = int(input("Enter a number:"))
  print(10 / num)
except ZeroDivisionError:
  print("Cannot divide by zero")
except ValueError:
  print("Inavlid input")
# Out:
# Enter a number:5.00
# Inavlid input

# %% [markdown]
# **3. else Block in exception handling**
#
#
# Concept : else runs when no exception occurs

# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))
    result = a / b
except ZeroDivisionError:
    print("Division by zero is not allowed")
else:
    print("Result:", result)
# Out:
# Enter a number: 4
# Enter another number: 2
# Result: 2.0

# %% [markdown]
# **4. finally Block**
#
# concept: Always executes
#          Used for cleanup (closing files, resources)

# %%
try:
    file = open("test.txt", "r")
    print(file.read())
except FileNotFoundError:
    print("File not found")
finally:
    print("Execution completed")
# Out:
# File not found
# Execution completed

# %% [markdown]
# **5. Raising an Exception**

# %%
age = int(input("Enter your age: "))

if age < 18:
    raise ValueError("Age must be 18 or above")

print("Access granted")
# Out:
# Enter your age: 18
# Access granted
